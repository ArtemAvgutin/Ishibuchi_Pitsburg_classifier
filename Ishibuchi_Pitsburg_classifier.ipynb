# %% [markdown]
# #Импортируем библиотеки

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

# %% [markdown]
# #Загружаем данные

# %%
df = pd.read_csv('Data.csv').drop('Id', axis=1)

# %%
df.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
# класс для построения правил ишибучи и расчетов достоверности

class Ishibuchi:
# класс выполняет обучение и предсказание на основе набора правил и данных.

    """
    Инициализация объекта класса
    Входные параметры: данные, имя переменной моделирования, часть тестового набора,
    часть набора проверки, список терминов в порядке возрастания (например, BS, MS, S, M, B, MB, BB)
    """

    def __init__(self, rules, class_len):
        self.rule_base = rules
        self.class_len = class_len

# метод выполняет обучение модели по переданным тренировочным данным, а также описаниям терминов
    def fit(self, X_train, y_train, *terms):
        self.terms = list(terms)

        self.variable_terms = self.terms_definition(X_train)

        self.rule_class_cf_assign(X_train, y_train, self.rule_base)

        return self
# метод определяет диапазоны значений для каждого термина на основе квантилей данных тренировочного набора.

    """
    Определение каждого переменного термина
    Входные параметры:
    Возврат: набор значений терминов для каждой переменной в наборе данных.
    """
# метод определяет диапазоны значений для каждого термина на основе квантилей данных тренировочного набора.
    def terms_definition(self, train_set):
        terms = self.terms
        terms_dict = {}
        quantiles = np.arange(0., 1., 1 / len(terms))[1:]

        for var in train_set.columns:
            terms_dict[var] = {k:None for k in terms}
            terms_quants = np.quantile(np.array(train_set[var]), quantiles)
            for term, quant in zip(terms, terms_quants):
                terms_dict[var][term] = quant

        return terms_dict


    """
    Функция, которая возвращает соответствующую функцию на основе текущего переменного термина в функции.
    Входные данные: термин переменной в правиле.
    Возврат: соответствующая функция
    """
# определяет функции принадлежности для каждого термина.
    def membership_function(self, term):

        def too_small(x, quant, right_border):
            if x >= right_border:
                return 0
            elif x <= quant:
                return 1
            else:
                return (right_border - x) / (right_border - quant)

        def too_big(x, quant, left_border):
            if x <= left_border:
                return 0
            if x >= quant:
                return 1
            else:
                return (x - left_border) / (quant - left_border)

        def dc_term():
            return 1

        def other_terms(x, quant, left_border, right_border):
            if (x <= left_border) | (x >= right_border):
                return 0
            elif left_border < x <= quant:
                return (x - left_border) / (quant - left_border)
            elif quant < x < right_border:
                return (right_border - x) / (right_border - quant)

        if term == self.terms[0]:
            return too_small
        elif term == self.terms[-2]:
            return too_big
        elif term == self.terms[-1]:
            return dc_term
        else:
            return other_terms


    """
    Функция для подсчета членства по всему правилу
    Входные параметры: правило, набор переменных
    Вывод: минимальная функция принадлежности по правилу.
    """
# метод вычисляет значение принадлежности для каждого правила исходя из переданных значений
    def count_membership_over_the_rule(self, rule:list, X):
        membership_values = []
        for t, v in zip(rule, X.keys()):
            member_func = self.membership_function(t)
            quant_index = self.terms.index(t)
            values = list(self.variable_terms[v].values())
            quant = values[quant_index]
            if 0 < quant_index < len(self.terms) - 2:
                left_border = values[quant_index - 1]
                right_border = values[quant_index + 1]

                membership_values.append(member_func(X[v], quant, left_border, right_border))
            elif quant_index == 0:
                right_border = values[quant_index + 1]

                membership_values.append(member_func(X[v], quant, right_border))

            elif quant_index == len(self.terms) - 2:
                left_border = values[quant_index - 1]

                membership_values.append(member_func(X[v], quant, left_border))

            else:
                membership_values.append(member_func())
        members_wo_zeros = [x for x in membership_values if x != 0]
        return min(members_wo_zeros) if len(members_wo_zeros) > 0 else 0


    """
    Функция для подсчета среднего членства в определенных class_samples
    Входные параметры: метка класса, правило из базы правил.
    Возврат: означает членство в классе
    """
# метод вычисляет суммарное значение принадлежности для каждого класса на основе правила и тренировочного набора.
    def class_membership(self, X_train, y_train, class_, rule):
        class_set = X_train.iloc[y_train[y_train == class_], :]
        membership_sum = 0

        for i in range(class_set.shape[0]):
            membership_sum += self.count_membership_over_the_rule(rule, class_set.iloc[i,:])

        return membership_sum / class_set.shape[0]


    """
    Cчетчик CF
    Входные параметры: словарь каждого бета-класса, истинная метка класса.
    """
# метод вычисляет значимость класса с помощью коэффициента достоверности для каждого класса.
    def cf_counter(self, class_betas_dict, true_class):
        true_class_beta = class_betas_dict[true_class]
        others_betas_mean = sum([class_betas_dict[x] for x in class_betas_dict.keys() if x != true_class]) / (self.class_len - 1)
        return (true_class_beta - others_betas_mean) / sum([class_betas_dict[x] for x in class_betas_dict.keys()])


    """
    Функция для назначения определенного класса каждому правилу в базе правил.
    Входные параметры: база правил
    """
# метод присваивает каждому правилу класс и коэффициент достоверности на основе тренировочного набора.
    def rule_class_cf_assign(self, X_train, y_train, rule_base):
        class_rule_assign = {}

        for rule in rule_base:
            betas = {class_:None for class_ in y_train.unique()}
            rule_s = ' '.join(rule)
            class_rule_assign[rule_s] = {}
            for class_ in betas.keys():
                betas[class_] = self.class_membership(X_train, y_train, class_, rule)

            class_rule_assign[rule_s]['class'] = list(betas.keys())[np.argmax(list(betas.values()))]
            class_rule_assign[rule_s]['cf'] = self.cf_counter(betas, class_rule_assign[rule_s]['class'])

        self.class_rule_assignment = class_rule_assign


    """
    Функция прогнозирования класса
    """
# метод предсказывает класс для новых данных X на основе правил и коэффициентов достоверности.
    def predict(self, X):
        best_class = None
        best_metric = -1
        for rule in self.class_rule_assignment.keys():
            div_rule = rule.split()
            metric = self.count_membership_over_the_rule(div_rule, X) * self.class_rule_assignment[rule]['cf']
            if metric > best_metric:
                best_metric = metric
                best_class = self.class_rule_assignment[rule]['class']

        return best_class

# %%
   '''
   Теперь класс Pittsburg, который выполняет генетический алгоритм для настройки и оптимизации модели.
   Тут инициализируются параметры алгоритма и создается начальная популяция правил
   '''

class Pittsburg:

    def __init__(self, X, y, *terms, initial_population=250, individual_length=10, mutation_probability=0.01, generation_length=100):
        self.generation_length=generation_length
        self.individual_length = individual_length
        self.initial_population = initial_population
        self.mutation_prob = mutation_probability
        self.X = X
        self.y = y
        self.terms = terms
        self.class_number = len(y.unique())

        self.population = [[np.random.choice(self.terms, self.X.shape[1])
                            for _ in range(individual_length)]
                            for _ in range(initial_population)]

# метод создает объекты ишибучи для каждого правила в популяции.
    def build_ishis(self):
        individs_dict = {}
        for i, ind in enumerate(self.population):
            individs_dict[i] = {'rules':ind,
                                'ishi':Ishibuchi(ind, self.class_number).fit(self.X, self.y, *self.terms)}

        self.individuals_dict = individs_dict

# метод вычисляет число правильно классифицированных элементов для данного правила.
    def NCP(self, individual):
        ncp = 0
        predictions = []
        for i in range(self.X.shape[0]):
            predictions.append(individual.predict(self.X.iloc[i, :]))
        number_of_correct = 0
        for p_class, t_class in zip(predictions, self.y):
            if p_class == t_class:
                number_of_correct += 1
        return number_of_correct
# метод вычисляет NCP для каждого правила в популяции и присваивает их соответствующим индивидуумам.
    def assign_ncp_to_individuals(self):
        for individ_key in self.individuals_dict.keys():
            self.individuals_dict[individ_key]['NCP'] = self.NCP(self.individuals_dict[individ_key]['ishi'])
# метод возвращает список значений NCP из индивидуумов.
    def take_ncps(self):
        ncps = []
        for individ_key in self.individuals_dict.keys():
            ncps.append(self.individuals_dict[individ_key]['NCP'])
        return ncps
# метод вычисляет вероятности выбора каждого индивидуума в качестве родителя.
    def assign_parent_probabilities(self):
        ncps = self.take_ncps()
        min_ncp = min(ncps)
        sum_ncp = sum(ncps)
        division = (sum_ncp - len(ncps)*min_ncp)
        for individ_key in self.individuals_dict.keys():
            self.individuals_dict[individ_key]['Parent_Probability'] = (self.individuals_dict[individ_key]['NCP'] - min_ncp) / (1 if division == 0 else division)
        return division

# метод выбирает индекс второго родителя из оставшихся индивидуумов.
    def choose_second_parent(self, first_parent_ind, parents_indecies):
        parents_indecies = list(parents_indecies.copy())
        parents_indecies.remove(first_parent_ind)

        second_parent = None
        while second_parent is None:
            parent_prob = np.random.uniform()
            for parent_ind in parents_indecies:
                if self.individuals_dict[parent_ind]['Parent_Probability'] >= parent_prob:
                    second_parent = parent_ind
                    break
        return second_parent

# метод выполняет операцию скрещивания двух родителей, создавая новое правило.
    def crossover(self, parent_one, parent_two):
        child_one = parent_one.copy()
        child_two = parent_two.copy()
        child = [child_one[j] if np.random.uniform() < 0.5 else child_two[j] for j in range(len(child_one))]
        return child

# метод применяет операцию скрещивания к популяции индивидуумов.
    def apply_uniform_crossover(self):
        new_population = []
        parents_indecies = list(self.individuals_dict.keys())
        for parent_ind in parents_indecies:
            parent_one = self.individuals_dict[parent_ind]['rules']
            parent_two = self.individuals_dict[self.choose_second_parent(parent_ind, parents_indecies)]['rules']

            child = self.crossover(parent_one, parent_two)

            new_population.append(child)

        return new_population

# метод мутации к новой популяции.
    def apply_mutation(self, new_population):
        for i in range(len(new_population)):
            for j in range(len(new_population[i])):
                mut = np.random.uniform()
                if mut <= self.mutation_prob:
                    new_population[i][j] = np.random.choice(self.terms, self.X.shape[1])

# метод создает новую популяцию путем применения скрещивания и мутации, а также сохраняет лучший индивидуум из предыдущего поколения.
    def new_generation(self):
        new_population = self.apply_uniform_crossover()
        self.apply_mutation(new_population)
        elite_index = np.argmax([x['NCP'] for x in self.individuals_dict.values()])
        random_from_new_population = np.random.randint(len(new_population))

        new_population[random_from_new_population] = self.individuals_dict[elite_index]['rules']

        del self.population
        del self.individuals_dict

        self.population = new_population

# метод выполняет генерацию новых поколений популяции и возвращает лучший индивидуум.
    def make_generations(self):
        print('Начало процесса')
        for i in range(1, self.generation_length + 1):
            print(f'/////////////////Generation {i - 1} start/////////////////////')
            print('Building population')
            self.build_ishis()
            print('Assigning ncps')
            self.assign_ncp_to_individuals()
            if i == self.generation_length:
                break
            print('Assigning initial probabilities')
            division = self.assign_parent_probabilities()
            print(f'Generation {i}. MAX NCP is : {np.max([x["NCP"] for x in self.individuals_dict.values()])}')
            if division == 0:
                print('All the individuals are same')
                break
            self.new_generation()
        return self.individuals_dict[np.argmax([x['NCP'] for x in self.individuals_dict.values()])]['ishi']

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop('quality', axis=1), df['quality'],
                                                    test_size=0.2, stratify=df['quality'])

# %%
ishibuchi = Pittsburg(X_train, y_train, 'TS', 'S', 'M', 'B', 'TB', 'DC',
                      initial_population=20,
                      individual_length=50,
                      generation_length=20) #Возьму 20 для быстроты работы

# %%
best_individ = ishibuchi.make_generations()
# Out:
# Start genetic process
# /////////////////Generation 0 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 1. MAX NCP is : 208
# /////////////////Generation 1 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 2. MAX NCP is : 208
# /////////////////Generation 2 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 3. MAX NCP is : 209
# /////////////////Generation 3 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 4. MAX NCP is : 209
# /////////////////Generation 4 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 5. MAX NCP is : 267
# /////////////////Generation 5 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 6. MAX NCP is : 267
# /////////////////Generation 6 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 7. MAX NCP is : 281
# /////////////////Generation 7 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 8. MAX NCP is : 296
# /////////////////Generation 8 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 9. MAX NCP is : 296
# /////////////////Generation 9 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 10. MAX NCP is : 296
# /////////////////Generation 10 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 11. MAX NCP is : 303
# /////////////////Generation 11 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 12. MAX NCP is : 303
# /////////////////Generation 12 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 13. MAX NCP is : 303
# /////////////////Generation 13 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 14. MAX NCP is : 310
# /////////////////Generation 14 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 15. MAX NCP is : 310
# /////////////////Generation 15 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 16. MAX NCP is : 335
# /////////////////Generation 16 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 17. MAX NCP is : 336
# /////////////////Generation 17 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 18. MAX NCP is : 337
# /////////////////Generation 18 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 19. MAX NCP is : 337
# /////////////////Generation 19 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 20. MAX NCP is : 339
# /////////////////Generation 20 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 21. MAX NCP is : 340
# /////////////////Generation 21 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 22. MAX NCP is : 344
# /////////////////Generation 22 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 23. MAX NCP is : 345
# /////////////////Generation 23 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 24. MAX NCP is : 345
# /////////////////Generation 24 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 25. MAX NCP is : 345
# /////////////////Generation 25 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 26. MAX NCP is : 346
# /////////////////Generation 26 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 27. MAX NCP is : 349
# /////////////////Generation 27 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 28. MAX NCP is : 349
# /////////////////Generation 28 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 29. MAX NCP is : 349
# /////////////////Generation 29 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 30. MAX NCP is : 353
# /////////////////Generation 30 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 31. MAX NCP is : 353
# /////////////////Generation 31 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 32. MAX NCP is : 353
# /////////////////Generation 32 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 33. MAX NCP is : 353
# /////////////////Generation 33 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 34. MAX NCP is : 355
# /////////////////Generation 34 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 35. MAX NCP is : 358
# /////////////////Generation 35 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 36. MAX NCP is : 363
# /////////////////Generation 36 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 37. MAX NCP is : 364
# /////////////////Generation 37 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 38. MAX NCP is : 364
# /////////////////Generation 38 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 39. MAX NCP is : 364
# /////////////////Generation 39 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 40. MAX NCP is : 364
# /////////////////Generation 40 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 41. MAX NCP is : 365
# /////////////////Generation 41 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 42. MAX NCP is : 365
# /////////////////Generation 42 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 43. MAX NCP is : 365
# /////////////////Generation 43 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 44. MAX NCP is : 365
# /////////////////Generation 44 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 45. MAX NCP is : 365
# /////////////////Generation 45 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 46. MAX NCP is : 365
# /////////////////Generation 46 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 47. MAX NCP is : 365
# /////////////////Generation 47 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 48. MAX NCP is : 365
# /////////////////Generation 48 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 49. MAX NCP is : 367
# /////////////////Generation 49 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 50. MAX NCP is : 367
# /////////////////Generation 50 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 51. MAX NCP is : 367
# /////////////////Generation 51 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 52. MAX NCP is : 367
# /////////////////Generation 52 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 53. MAX NCP is : 367
# /////////////////Generation 53 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 54. MAX NCP is : 369
# /////////////////Generation 54 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 55. MAX NCP is : 369
# /////////////////Generation 55 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 56. MAX NCP is : 369
# /////////////////Generation 56 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 57. MAX NCP is : 371
# /////////////////Generation 57 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 58. MAX NCP is : 371
# /////////////////Generation 58 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 59. MAX NCP is : 371
# /////////////////Generation 59 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 60. MAX NCP is : 371
# /////////////////Generation 60 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 61. MAX NCP is : 371
# /////////////////Generation 61 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 62. MAX NCP is : 371
# /////////////////Generation 62 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 63. MAX NCP is : 371
# /////////////////Generation 63 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 64. MAX NCP is : 371
# /////////////////Generation 64 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 65. MAX NCP is : 371
# /////////////////Generation 65 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 66. MAX NCP is : 371
# /////////////////Generation 66 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 67. MAX NCP is : 371
# /////////////////Generation 67 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 68. MAX NCP is : 373
# /////////////////Generation 68 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 69. MAX NCP is : 373
# /////////////////Generation 69 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 70. MAX NCP is : 373
# /////////////////Generation 70 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 71. MAX NCP is : 375
# /////////////////Generation 71 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 72. MAX NCP is : 375
# /////////////////Generation 72 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 73. MAX NCP is : 375
# /////////////////Generation 73 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 74. MAX NCP is : 375
# /////////////////Generation 74 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 75. MAX NCP is : 375
# /////////////////Generation 75 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 76. MAX NCP is : 375
# /////////////////Generation 76 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 77. MAX NCP is : 375
# /////////////////Generation 77 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 78. MAX NCP is : 375
# /////////////////Generation 78 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 79. MAX NCP is : 375
# /////////////////Generation 79 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 80. MAX NCP is : 375
# /////////////////Generation 80 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 81. MAX NCP is : 377
# /////////////////Generation 81 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 82. MAX NCP is : 377
# /////////////////Generation 82 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 83. MAX NCP is : 377
# /////////////////Generation 83 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 84. MAX NCP is : 377
# /////////////////Generation 84 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 85. MAX NCP is : 377
# /////////////////Generation 85 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 86. MAX NCP is : 377
# /////////////////Generation 86 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 87. MAX NCP is : 377
# /////////////////Generation 87 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 88. MAX NCP is : 377
# /////////////////Generation 88 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 89. MAX NCP is : 377
# /////////////////Generation 89 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 90. MAX NCP is : 378
# /////////////////Generation 90 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 91. MAX NCP is : 378
# /////////////////Generation 91 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 92. MAX NCP is : 378
# /////////////////Generation 92 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 93. MAX NCP is : 378
# /////////////////Generation 93 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 94. MAX NCP is : 378
# /////////////////Generation 94 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 95. MAX NCP is : 378
# /////////////////Generation 95 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 96. MAX NCP is : 378
# /////////////////Generation 96 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 97. MAX NCP is : 378
# /////////////////Generation 97 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 98. MAX NCP is : 378
# /////////////////Generation 98 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 99. MAX NCP is : 378
# /////////////////Generation 99 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 100. MAX NCP is : 378
# /////////////////Generation 100 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 101. MAX NCP is : 378
# /////////////////Generation 101 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 102. MAX NCP is : 378
# /////////////////Generation 102 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 103. MAX NCP is : 378
# /////////////////Generation 103 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 104. MAX NCP is : 379
# /////////////////Generation 104 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 105. MAX NCP is : 379
# /////////////////Generation 105 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 106. MAX NCP is : 379
# /////////////////Generation 106 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 107. MAX NCP is : 379
# /////////////////Generation 107 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 108. MAX NCP is : 379
# /////////////////Generation 108 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 109. MAX NCP is : 379
# /////////////////Generation 109 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 110. MAX NCP is : 381
# /////////////////Generation 110 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 111. MAX NCP is : 381
# /////////////////Generation 111 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 112. MAX NCP is : 381
# /////////////////Generation 112 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 113. MAX NCP is : 381
# /////////////////Generation 113 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 114. MAX NCP is : 381
# /////////////////Generation 114 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 115. MAX NCP is : 381
# /////////////////Generation 115 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 116. MAX NCP is : 381
# /////////////////Generation 116 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 117. MAX NCP is : 381
# /////////////////Generation 117 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 118. MAX NCP is : 381
# /////////////////Generation 118 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 119. MAX NCP is : 381
# /////////////////Generation 119 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 120. MAX NCP is : 381
# /////////////////Generation 120 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 121. MAX NCP is : 381
# /////////////////Generation 121 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 122. MAX NCP is : 381
# /////////////////Generation 122 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 123. MAX NCP is : 381
# /////////////////Generation 123 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 124. MAX NCP is : 381
# /////////////////Generation 124 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 125. MAX NCP is : 381
# /////////////////Generation 125 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 126. MAX NCP is : 381
# /////////////////Generation 126 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 127. MAX NCP is : 381
# /////////////////Generation 127 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 128. MAX NCP is : 381
# /////////////////Generation 128 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 129. MAX NCP is : 381
# /////////////////Generation 129 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 130. MAX NCP is : 382
# /////////////////Generation 130 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 131. MAX NCP is : 382
# /////////////////Generation 131 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 132. MAX NCP is : 382
# /////////////////Generation 132 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 133. MAX NCP is : 382
# /////////////////Generation 133 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 134. MAX NCP is : 382
# /////////////////Generation 134 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 135. MAX NCP is : 384
# /////////////////Generation 135 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 136. MAX NCP is : 385
# /////////////////Generation 136 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 137. MAX NCP is : 385
# /////////////////Generation 137 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 138. MAX NCP is : 385
# /////////////////Generation 138 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 139. MAX NCP is : 385
# /////////////////Generation 139 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 140. MAX NCP is : 385
# /////////////////Generation 140 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 141. MAX NCP is : 385
# /////////////////Generation 141 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 142. MAX NCP is : 385
# /////////////////Generation 142 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 143. MAX NCP is : 385
# /////////////////Generation 143 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 144. MAX NCP is : 385
# /////////////////Generation 144 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 145. MAX NCP is : 385
# /////////////////Generation 145 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 146. MAX NCP is : 387
# /////////////////Generation 146 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 147. MAX NCP is : 387
# /////////////////Generation 147 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 148. MAX NCP is : 387
# /////////////////Generation 148 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 149. MAX NCP is : 387
# /////////////////Generation 149 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 150. MAX NCP is : 387
# /////////////////Generation 150 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 151. MAX NCP is : 388
# /////////////////Generation 151 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 152. MAX NCP is : 388
# /////////////////Generation 152 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 153. MAX NCP is : 388
# /////////////////Generation 153 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 154. MAX NCP is : 388
# /////////////////Generation 154 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 155. MAX NCP is : 388
# /////////////////Generation 155 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 156. MAX NCP is : 388
# /////////////////Generation 156 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 157. MAX NCP is : 388
# /////////////////Generation 157 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 158. MAX NCP is : 388
# /////////////////Generation 158 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 159. MAX NCP is : 388
# /////////////////Generation 159 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 160. MAX NCP is : 389
# /////////////////Generation 160 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 161. MAX NCP is : 389
# /////////////////Generation 161 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 162. MAX NCP is : 389
# /////////////////Generation 162 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 163. MAX NCP is : 389
# /////////////////Generation 163 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 164. MAX NCP is : 389
# /////////////////Generation 164 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 165. MAX NCP is : 389
# /////////////////Generation 165 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 166. MAX NCP is : 389
# /////////////////Generation 166 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 167. MAX NCP is : 389
# /////////////////Generation 167 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 168. MAX NCP is : 389
# /////////////////Generation 168 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 169. MAX NCP is : 389
# /////////////////Generation 169 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 170. MAX NCP is : 389
# /////////////////Generation 170 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 171. MAX NCP is : 389
# /////////////////Generation 171 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 172. MAX NCP is : 389
# /////////////////Generation 172 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 173. MAX NCP is : 389
# /////////////////Generation 173 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 174. MAX NCP is : 389
# /////////////////Generation 174 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 175. MAX NCP is : 389
# /////////////////Generation 175 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 176. MAX NCP is : 389
# /////////////////Generation 176 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 177. MAX NCP is : 390
# /////////////////Generation 177 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 178. MAX NCP is : 390
# /////////////////Generation 178 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 179. MAX NCP is : 390
# /////////////////Generation 179 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 180. MAX NCP is : 390
# /////////////////Generation 180 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 181. MAX NCP is : 390
# /////////////////Generation 181 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 182. MAX NCP is : 390
# /////////////////Generation 182 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 183. MAX NCP is : 390
# /////////////////Generation 183 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 184. MAX NCP is : 390
# /////////////////Generation 184 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 185. MAX NCP is : 395
# /////////////////Generation 185 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 186. MAX NCP is : 395
# /////////////////Generation 186 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 187. MAX NCP is : 395
# /////////////////Generation 187 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 188. MAX NCP is : 395
# /////////////////Generation 188 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 189. MAX NCP is : 395
# /////////////////Generation 189 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 190. MAX NCP is : 395
# /////////////////Generation 190 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 191. MAX NCP is : 395
# /////////////////Generation 191 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 192. MAX NCP is : 395
# /////////////////Generation 192 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 193. MAX NCP is : 395
# /////////////////Generation 193 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 194. MAX NCP is : 395
# /////////////////Generation 194 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 195. MAX NCP is : 395
# /////////////////Generation 195 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 196. MAX NCP is : 395
# /////////////////Generation 196 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 197. MAX NCP is : 396
# /////////////////Generation 197 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 198. MAX NCP is : 396
# /////////////////Generation 198 start/////////////////////
# Building population
# Assigning ncps
# Assigning initial probabilities
# Generation 199. MAX NCP is : 396
# /////////////////Generation 199 start/////////////////////
# Building population
# Assigning ncps

# %%
predictions = []
for i in range(X_test.shape[0]):
    predictions.append(best_individ.predict(X_test.iloc[i, :]))

# %%
true_answers = 0
for pr, test in zip(predictions, y_test):
    if pr == test:
        true_answers += 1

# %%
print(f'Точность работы алгоритма: {round(true_answers * 100/y_test.shape[0])} %')
# Out:
# Точность работы алгоритма: 43 %

# %% [markdown]
# ## Низкая точность это алгоритма может быть связана с несколькими возможными причинами:
#
# * Недостаточное количество обучающих данных: Если объем данных, на которых обучается алгоритм, слишком мал, то алгоритм может не иметь достаточно информации для того, чтобы выучить правильные закономерности и принимать точные решения.
#
# * Переобучение (overfitting): Если модель слишком сложная или имеет слишком много параметров, она может "запоминать" обучающие данные вместо того, чтобы обобщать их основные закономерности. Это может привести к плохим результатам на новых данных.
#
# * Недостаточно эффективные признаки: Если выбранные признаки не содержат достаточно информации, чтобы корректно классифицировать данные, то точность алгоритма может оставаться низкой.
#
# * Неверно настроенные гиперпараметры: Некоторые алгоритмы машинного обучения имеют гиперпараметры, которые необходимо правильно настроить для достижения оптимальной производительности. Если гиперпараметры не правильно настроены, это может привести к плохим результатам.
#
# * Некорректная предобработка данных: Неправильная обработка или недостаточная чистка данных перед обучением алгоритма также может привести к низкой точности.
#
# ### Чтобы улучшить точность питсбургского алгоритма, рекомендуется провести анализ и проверить вышеперечисленные возможные причины. Может потребоваться изменить подход к обработке данных, выбору признаков, настройке модели или увеличить объем обучающих данных для более точного обучения алгоритма.
